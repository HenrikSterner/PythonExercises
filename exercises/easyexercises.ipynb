# %% [markdown]
# # Nybegynder øvelser
# Nedenfor ses en række opgaver til folk, der netop er startet med at programmere i Python.
#
# # Opgave 1
# Skriv et program der printer "Hej med dig. Jeg elsker at kode" ud på skærmen. Udvid nu programmet med følgende:
#
# - Skriv en ny print-sætning, der printer: "Jeg elsker at kode i Python"
# - Indsæt en kommentar i koden, der forklarer hvad programmet gør
# - Skriv en ny print-sætning, der printer: "Jeg elsker at kode i Python" i fed skrift (brug `\033[1m` for at gøre teksten fed)
# - Indsæt en mulitiline kommentar, der forklarer hvad programmet gør
# - Skriv en ny print-sætning, der printer: "Jeg elsker at kode i Python" i kursiv (brug `\033[3m` for at gøre teksten kursiv)

# %% [markdown]
# # Opgave 2
#
# I det følgende skal vi arbejde med variabler i Python:
#
# - Lav en variable til at opbevare en cirkels radius og indlæs den med et tal. Skriv noget kode der printer arealet og omkredsen af cirklen.
# - Lav en variabel til at opbevare en rektangels længde og bredde. Skriv noget kode der printer arealet og omkredsen af rektanglet.
# - Lav en variabel til at opbevare en trekants grundlinje og højde. Skriv noget kode der printer arealet af trekanten.
# - Lav to variabler til at opbevare to tal. Skriv noget kode der printer summen, forskellen, produktet og kvotienten af de to tal.

# %% [markdown]
# # Opgave 3
# Du kan gemme input fra brugeren i $x$ ved at skrive<br>
# ```python
# x=input("Skriv dit navn: ")
# ```
#
# - Skriv et program der beder brugeren om at indtaste fornavn og efternavn og bagefter printer den "Hej " efterfulgt at hele navnet.
#
# Hvis input er et tal, så vil det blive gemt som en streng. Hvis du vil have det som et tal, skal du konvertere det til et tal ved at skrive:
#
# ```python
# x=int(input("Skriv et tal: "))  # For heltal
# x=float(input("Skriv et tal: "))  # For decimaltal
# x=bool(input("Skriv True eller False: "))  # For boolske værdier
# ```
#
# - Skriv et program der beder brugeren om at indtaste to tal og bagefter printer summen af de to tal.
# - Skriv et program der beder brugeren om at indtaste en temperatur i Celsius og bagefter printer temperaturen i Fahrenheit. (Formlen er: F = C * 9/5 + 32)
# - Skriv et program der konverterer kroner til euro. (Formlen er: Euro = Kr / 7.44)
# - Skriv et program der tager et kalorietal og omregner det til joule. (Formlen er: Joule = Kalorie * 4.184)
# - Skriv et program der tager et kalorietal og omregner det til big macs. (Formlen er: Big Mac = Kalorie / 500)
# - Skriv et program der tager et kommatal og kun printer den hele del af tallet. (Brug `int()` funktionen til at konvertere et tal til et heltal)

# %% [markdown]
# # Opgave 4
#
# - Bed brugeren om at indtaste en alder og fortæl brugeren om vedkommende er myndig eller ej (18 eller derover)
# - Skriv et program, der tager tre variable og undersøger om summen er større end 100
# - Skriv et program, der tager to variable og undersøger om den første er større end den anden
#
# # Opgave 5
#
# I de følgende små opgaver skal du arbejde med variabler og datatyper i Python hvor du skal identificere og ændre variabler, bruge `type()` funktionen, og arbejde med forskellige datatyper som strenge, heltal, flydende tal og boolske værdier.
#
# a. **Identificér variabler og datatyper**
#    Betragt følgende kode:
#    ```python
#    navn = "Parmigiano Reggiano"
#    kg_pris = 39.95
#    antal_gram = 250
#    paa_lager = True
#    ```
#    - Hvilke variabler findes?
#    - Hvilken datatype har hver værdi?
#
# b. **Brug af `type()`**
#    Skriv et program, der opretter følgende variabler og udskriver deres datatype:
#    ```python
#    navn = "Sara"
#    alder = 17
#    hoejde = 1.68
#    er_elev = False
#    ```
#
# c. **Ændring af variabel**
#    Start med følgende:
#    ```python
#    alder = 17
#    print("Alder")
#    print(alder)
#    alder = 18
#    print("Ny alder")
#    print(alder)
#    ```
#
# d. **Input og `type()`**
#    ```python
#    antal_gram = input("Hvor mange gram ønsker du? ")
#    print(type(antal_gram))
#    ```
#    - Skriv 100 i terminalen.
#    - Hvilken datatype har `antal_gram`?
#
# e. **Brug af `int()` til beregning**
#    Udvid forrige opgave:
#    ```python
#    pris_for_100g = 39.95
#    antal_gram = int(input("Hvor mange gram ønsker du? "))
#    pris = pris_for_100g * antal_gram / 100
#    print(pris)
#    ```
#
# f. **Typecasting**
#    Prøv følgende:
#    ```python
#    print(int(100.0))
#    print(int("100"))
#    print(int(True))
#    print(int(False))
#    print(float("12.5"))
#    print(str(123))
#    print(bool(0))
#    print(bool(1))
#    ```
#
# g. **Minutter til timer og minutter**
#    ```python
#    minutter = 133
#    timer = minutter // 60
#    rester = minutter % 60
#    print(timer, "timer og", rester, "minutter")
#    ```
#
# h. **Sekunder til timer, minutter og sekunder**
#
#    ```python
#    sekunder = 3672
#    timer = sekunder // 3600
#    minutter = (sekunder % 3600) // 60
#    rester = sekunder % 60
#    print(timer, "t", minutter, "m", rester, "s")
#    ```
#
# i. **Angiv datatyper (uden `type()`)**
#    Hvad er datatypen for følgende udtryk:
# ```python
# "123"
# 123
# "12.3"
# 12.3
# True
# "True"
# ```
# j. **Formatering og konkatenering**
# Opret følgende variabler:
#
# ```python
# navn = "Sara"
# adresse = "Paradisvej"
# husnummer = 11
# ```
#
# Print med f-string navn, adresse og husnummer, og bagefter med konkatenering (dvs. `+` operatoren):
#
#
# k. **Escape sekvenser**
# Forklar hvad der sker:
#
# ```python
# tekst = "Titlen er \"I like the flowers\""
# akkorder = "C \\ G \\ Am \\ F"
# print(tekst)
# print(akkorder)
# ```
#
# l. **Boolean-operatorer**
# Hvad printes?
#
# ```python
# x = True
# y = False
# print(not x)
# print(x and y)
# print(x or y)
# ```
#
# m. **Arbejde med lister og muterbarhed**
# Test følgende:
#
# ```python
# frugter = ["æble", "pære", "banan"]
# frugter.append("kiwi")
# frugter[1] = "appelsin"
# print(frugter)
# ```
#
# n. **Ændring af tekststreng via list**
# Fjern bogstavet "h" i følgende:
#
# ```python
# navn = "Sarah Madsen"
# navn_list = list(navn)
# navn_list.remove("h")
# navn_ny = "".join(navn_list)
# print(navn_ny)
# ```
#
# o. **Liste af ordbøger**
# Opret en liste med dicts med ostedata og print dem ud på skærmen:
#
# ```python
# oste = [
#     {"navn": "Cheddar", "pris": 30.0, "voksen": True},
#     {"navn": "Gouda", "pris": 25.0, "voksen": False},
#     {"navn": "Brie", "pris": 35.0, "voksen": True}
# ]
#
# for ost in oste:
#     print(f"Navn: {ost['navn']}, Pris: {ost['pris']}, Voksen: {ost['voksen']}")
# ```
#
# Prøv nu at gøre det samme med nogle navne, adresser og telefonnumre. Opret en liste med dicts, hvor hver dict indeholder navn, adresse og telefonnummer. Print dem ud på skærmen.
#
#
#
#
# # Opgave 6
# Skriv et program der undersøger om et tal er lige eller ulige. Man kan bruge modulo operatoren "%" til at undersøge om der er en rest ved division med $2$. F.eks. kunne programmet begynde således:
# if(x%2==0):

# %% [markdown]
# # Opgave 7
# Herunder skal du arbejde med løkker i Python:
#
# - Brug en for-løkke til at skrive tallene 1 til 10 ud på skærmen.
# - Udvid programmet så det også skriver summen af tallene 1 til 10 ud på skærmen.
# - Brug en for-løkke til at skrive de lige tal mellem 1 og 100 ud på skærmen.
# - Brug en for-løkkke til at tilføje hvert tal mellem 1 og 100 til en liste, som du selv opretter.
# - Brug en for-løkke til at skrive multiplikationstabellen fra 1 til 10 ud på skærmen.
# - Brug en for-løkke til at skrive n stjerner (*) på skærmen, hvor n er et tal, som brugeren indtaster.
# - Lav en liste med navne og brug en for-løkke til at skrive hvert navn ud på skærmen.
# - Lav en ny liste med aldre og brug en for-løkke til at skrive hvert tal ud på skærmen.
#
#
#
#
# # Opgave 8
# Herunder skal du arbejde med while-løkker i Python:
#
# - Brug en while-løkke til at skrive de lige tal mellem 1 og 100 ud på skærmen.
# - Brug en while-løkke til at beregne summen af de lige tal mellem 1 og 100.
# - Brug en while-løkke til at tælle ned fra 10 til 1 og skrive hvert tal ud på skærmen.
# - Opret en liste med 10 tal og brug en while-løkke til at skrive hvert tal ud på skærmen.
# - Brug en while-løkke til at vente på at brugeren indtaster ti forskellige tal og skriv hvert tal ud på skærmen.
# - Brug en while-løkke til at finde det største tal i en liste med 10 tal.
#
#
#
#
# # Opgave 9
# I det følgende skal du arbejde med løkker inde i løkker i Python:
#
# 1. Brug en for-løkke til at gå gennem en liste af lister, og brug en while-løkke til at udskrive alle elementer i hver underliste.
# 2. Brug en for-løkke til at udskrive tallene fra 1 til 5, og for hvert tal, brug en while-løkke til at tælle ned fra tallet til 1.
# 3. Opret en 2D-liste med tal. Brug en while-løkke til at gå gennem rækkerne, og en for-løkke til at udskrive alle tal i hver række.
# 4. Brug en for-løkke til at spørge brugeren om input 3 gange, og for hvert input, brug en while-løkke til at validere, at input er et tal.
# 5. Brug en for-løkke til at udskrive alle bogstaver i en tekst, og for hvert bogstav, brug en while-løkke til at gentage bogstavet så mange gange som dets position i teksten.
# 6. Opret en liste med 5 tal. Brug en while-løkke til at gå gennem listen, og for hvert tal, brug en for-løkke til at udskrive tallet så mange gange som dets værdi.
# 7. Brug en for-løkke til at udskrive tallene fra 1 til 10, og for hvert tal, brug en while-løkke til at tjekke om tallet er primtal (ved at prøve at dividere med mindre tal).
# 8. Opret en liste med ord. Brug en while-løkke til at gå gennem listen, og for hvert ord, brug en for-løkke til at udskrive hvert bogstav.
# 9. Brug en for-løkke til at udskrive tallene fra 1 til 5, og for hvert tal, brug en while-løkke til at lægge tallet sammen med de foregående og udskrive summen.
# 10. Opret en 3D-liste. Brug en while-løkke til at gå gennem de ydre lister, en for-løkke til at gå gennem de midterste lister, og en while-løkke til at udskrive alle elementer i de inderste lister.
#
# # Opgave 10
# I det følgende skal du arbejde med boolske udtryk og varibler i Python:
#
# 1. Skriv et program, der tjekker om to variable har samme værdi og udskriver True eller False.
# 2. Opret to variable med tal og brug et boolsk udtryk til at tjekke om de begge er større end 10.
# 3. Opret to variable med tekst og tjek om de er ens (brug ==).
# 4. Skriv et program, der tjekker om to variable er forskellige (brug !=).
# 5. Opret to variable og tjek om mindst én af dem er lig med 0 (brug or).
# 6. Opret to variable og tjek om begge er positive tal (brug and).
# 7. Skriv et program, der tjekker om to variable har samme type (brug type()).
# 8. Opret to variable og tjek om den ene er større end den anden.
# 9. Skriv et program, der tjekker om to variable har samme længde (hvis de er strenge eller lister).
# 10. Opret to variable og brug et boolsk udtryk til at tjekke om de begge er tomme (f.eks. "" eller []).
#
# # Opgave 11
# Skriv et program der udregner løsningen til udtrykket (x+y)*(x-y) hvor du selv sætter x og y til bestemte værdier
#
# # Opgave 12
# Skriv et program der løser en andengradsligning og finder toppunktet
#
# # Opgave 13
# Skriv et program, der givet længden af to sider i en retvinklet trekant, finder længden af den tredje.
#
# # Opgave 14
# Skriv et program, der finder ud af om et element eksisterer i en liste.
#
# # Opgave 15
# Skriv noget kode der tager en streng printer det første og sidste element i strengen.
#
# # Opgave 16
# Tilføj de første 100 tal til en liste, som du selv opretter.
#
# # Opgave 17
# Lav et program, der undersøger længden af to givne lister.
#
# # Opgave 18
# Skriv et program, der undersøger vha en løkke om to lister er ens. Eksperimenter selv med forskellige lister.
#
# # Opgave 19
# Print multiplikationstabellen fra 1 til 10.
#
# # Opgave 20
# Lav et program der givet et tal n først printer n stjerner (*) og på næste linje n-1 osv.
#
# # Opgave 21
# Man kan indlæse en fil i Python således:
#
# ```python
# f = open("D:\\myfiles\welcome.txt", "r")
# print(f.read())
# ```
#
# Lav en simpel tekst fil med nogle linjers tekst. Indlæs filen og print det ud på skærmen.
#
# # Opgave 22
# Man kan indlæse løbe linje for linje igennem en fil i Python således:
#
# ```python
# f = open("demofile.txt", "r")
# for x in f:
#   print(x)
# ```
#
# Indlæs en fil med 10 linjers tekst. Indlæs kun hver anden linje.
#
# # Opgave 23
# Prøv at tilføje indhold til filen vha argumentet "a". Det kan gøres generelt således:
# ```python
# f = open("demofile2.txt", "a")
# f.write("Now the file has more content!")
# f.close()
# ```
# Indlæs filen og se at der er fundet en tilføjelse sted. Tilføj nu tallene 1 til 10 i slutningen af filen
#
# # Opgave 24
# Du kan overskrive en fil på tilsvarende vis vha argumentet "w". Prøv at overskrive den valgte fil.
#
# # Opgave 25
# Du kan slette en fil således:
# ```python
# import os
# if os.path.exists("demofile.txt"):
#   os.remove("demofile.txt")
# else:
#   print("The file does not exist")
# ```
#
# Prøv at slette en fil.
#
# # Opgave 26
# Lav en liste med navne. Skriv dem til en fil.
#
# # Opgave 27
# Lav en liste med 100 tilfældige heltal mellem 0 og 10. Gem listen i fil.
# Indlæs dem og undersøg hvor mange lige tal der findes.
# Du kan generere et tilfældigt heltal således:
#
# ```python
# import random
# random.randint(0, 10) # tallet er mellem 0 og 10
# ```
# Betragt nu en liste a = [1,2,3,4,3,2,1].
# Skriv noget kode der fjerner dupletter.
#
# # Opgave 28
# Betragt følgend lister:
#
# ```python
# a= [4,3,5,1,2,6]
# b= [32,4,5,62,4]
# ```
# I. Print det 0'te element ud for begge lister (hint: a[0] og b[0]).
# II. Print det tredje element ud for begge lister
# III. Lav en løkke der printer først det første element i a og bagefter det første element i b. Prøv f.eks. med følgende start:
# ```
# for (x,y) in zip(a,b):
#   #tilføj noget kode
# ```
# Hvad gør zip mon?
#
# # Opgave 29
# Skriv en løkke, der finder ud af hvor 4 er placeret i listerne a og b. Altså index.
#
#
# # Opgave 30
# Afprøv nu strukturen liste[x:y], som udvælger elementerne med index x til y fra liste.
# Brug notationen til at hente elementerne 5,1 og 2 ud fra liste a i opgave 28.
#
# # Opgave 31
# Generer med en tilfældighedsgenerator tre heltal mellem 0 og 2 dvs. 0, 1 eller 2.
# Find ud af hvilket er mindst.
#
# # Opgave 32
# I det følgende skal man springe videre til næste iteration hvis i er 3 (hint: slå continue op) og man skal springe ud af løkken hvis den bliver 5 (hint: slå break op):
#
# ```python
# i = 0
# while i < 6:
#   i += 1
#   if i == 3:
#     # udfyld noget kode
#
#   print(i)
# ```
# # Opgave 33
# Betragt listen:
# ```python
# fruits = ["apple", "banana", "cherry"]
# ```
# Tilføj nogle forskellige frugter til listen både til slut i listen og før.
#
# # Opgave 34
# Der findes en lang række operationer på lister. Bl.a. følgende:
# * append()	Adds an element at the end of the list
# * clear()	Removes all the elements from the list
# * copy()	Returns a copy of the list
# * count()	Returns the number of elements with the specified value
# * extend()	Add the elements of a list (or any iterable), to the end of the current list
# * index()	Returns the index of the first element with the specified value
# * insert()	Adds an element at the specified position
# * pop()	Removes the element at the specified position
# * remove()	Removes the first item with the specified value
# reverse()	Reverses the order of the list
# * sort()	Sorts the list
#
# Udvælg mindst tre forskellige operationer og prøv dem af på nogle lister.
#
# # Opgave 35
# Der findes en lang række streng metoder til at operere på strenge. Bl.a.:
# *capitalize()
# *casefold()
# *center()
# *count()
# *encode()
# *endswith()
# *find()
# *format()
# *index()
# *isalnum()
# *isalpha()
# *isdecimal()
# *isdigit()
# *islower()
# *isnumeric()
# *replace()
#
# Undersøg hvad disse metoder gør og giv eksempler på nogle af dem i praksis.
#
# # Opgave 36
# Skriv kode der kan tjekke om en variable
# * kun består af tal
# * kun består af bogstaver
# * består af et decimal tal
#
# Hint: Brug nogle af metoderne ovenfor.
#
#
# # Opgave 37
# Man kan hente en værdi ud af en dictionary ved brug af get:
#
# ```python
# car = {
#   "brand": "Ford",
#   "model": "Mustang",
#   "year": 1964
# }
# x = car.get("model")
# print(x)
# ```
# Prøv nu at hente værdien ´Thirty´ ud:
# ```python
# {'Ten': 10, 'Twenty': 20, 'Thirty': 30}
# ```
#
# # Opgave 38
# Du kan konstruere en dictionary ved hjælp af 2 lister:
#
# ```python
#
# keys = ['Ten', 'Twenty', 'Thirty']
# values = [10, 20, 30]
#
# res_dict = dict(zip(keys, values))
# print(res_dict)
#
# ````
# Prøv koden.
#
# # Opgave 39
# Du kan sammenkæde to dictionaries ved brug af copy:
#
# ```python
# dict1 = {'Ten': 10, 'Twenty': 20, 'Thirty': 30}
# dict2 = {'Thirty': 30, 'Fourty': 40, 'Fifty': 50}
#
# dict3 = dict1.copy()
# dict3.update(dict2)
# print(dict3)
# ```
# Prøv koden af.
#
# # Opgave 40
# Lav nu to lister med 5 navne og 5 aldre i to lister.
# Omdan den til en dictionary.
#
# Lav nu en ny dictionary med to navne og 2 aldre. Sammenkæd de to dictionaries.
